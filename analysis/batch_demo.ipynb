# %% [markdown]
# Note: if we turn off scattering *right* at recombination, does p(k) at the initial redshift of ARES come out the same or not?

# %%
from millicharge.batch import SimGroup

sims = SimGroup('test.yaml')

# %%
sims.info
# Out:
# {'all': {'initial_redshift': 100,
#   'epsilon_dt': 0.001,
#   'hmf_model': 'Tinker10',
#   'verbose': False},
#  'dmb_dmb': {'label': 'DMB; DMB p(k)',
#   'include_dm': True,
#   'sigma_dmb': '1e-40',
#   'm_dmb': 1.0,
#   'use_classy_pk': True},
#  'lcdm': {'label': 'LCDM', 'include_dm': False},
#  'dmb_lcdm': {'label': 'DMB; LCDM p(k)',
#   'include_dm': True,
#   'sigma_dmb': '1e-40',
#   'm_dmb': 1.0,
#   'use_classy_pk': False}}

# %%
# sims.test()

# %%
# sims['dmb_dmb'].run()

# %%
from multiprocessing import Pool

pool = Pool(3)
sims.run(pool=pool)

# %%
sims.global_signature();

# %%
global_signature_plot = sims.global_signature()

# %%
lines = global_signature_plot.axes[0].lines

# %%
xdata, ydata = lines[0].get_data()

# %%
global_signature_plot.
# Out:
# []

# %%
sims.global_signature();
# Out:
# /Users/tmorton/miniconda3/envs/millicharge/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = sims.history_df('dmb_dmb')

# %%
for sim in sims:
    print(sim)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-cd79b78fdf69> in <module>
# ----> 1 for sim in sims:
#       2     print(sim)
#
# ~/repositories/millicharge21cm/millicharge/batch.py in __getitem__(self, item)
#      76
#      77     def __getitem__(self, item):
# ---> 78         return self.global_sims[item]
#      79
#      80     def _get_global_sims(self):
#
# KeyError: 0

# %%
for name in sims.analysis.keys():
    assert sims.history_df(name).isnull().sum().sum() == 0
